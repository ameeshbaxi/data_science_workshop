# %% [markdown]
# ### Convert CSV into SQLITE Database
#
# #### Data-Set
# For this assignment purpose, the dataset will be used from [Kaggle Competition](https://www.kaggle.com/c/avazu-ctr-prediction/). Mostlikely, the same challenge will be capstone project as well.
#
# #### Database
# The training data base is access of **6Gb** when unzipped. To start with this for exercise, the data in csv will be converted into sqlite database and sql queries will be used for exploration purpose

# %%
import pandas as pd

df = pd.read_csv('../capstone_project/data/train.csv', nrows=2)
print(df.columns)
df.head()
# Out:
# Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')
#                      id  click      hour    C1  banner_pos   site_id  \
# 0   1000009418151094273      0  14102100  1005           0  1fbe01fe
# 1  10000169349117863715      0  14102100  1005           0  1fbe01fe
#
#   site_domain site_category    app_id app_domain ...  device_type  \
# 0    f3845767      28905ebd  ecad2386   7801e8d9 ...            1
# 1    f3845767      28905ebd  ecad2386   7801e8d9 ...            1
#
#   device_conn_type    C14  C15  C16   C17  C18  C19     C20  C21
# 0                2  15706  320   50  1722    0   35      -1   79
# 1                0  15704  320   50  1722    0   35  100084   79
#
# [2 rows x 24 columns]

# %% [markdown]
# ### Converting csv file into sqllite database
# Note: The actual function call is commented out so that this function does not get called all the time.

# %%
import pandas as pd
from sqlalchemy import create_engine # database connection
import datetime as dt
import os

def convert_csv_to_sqldb(csv_data, sql_data=None):
    start = dt.datetime.now()
    chunksize = 20000
    j = 0
    index_start = 1
    
    if sql_data is None:
        abs_path = os.path.dirname(os.path.abspath(csv_data))
        db_name = os.path.basename(csv_data).split('.')[0] + '.db'
        sql_path = os.path.join(abs_path, db_name)
        if os.path.exists(sql_path):
            os.remove(sql_path)
        sql_path = 'sqlite:///' + sql_path
    else:
        sql_path = sql_data
    
    # Initializes database
    disk_engine = create_engine(sql_path)
    
    for df in pd.read_csv(csv_data, chunksize=chunksize, iterator=True, encoding='utf-8'):
    
        df.hour = df.hour.astype(str)
        df.hour = df.hour.str[:2] + '-' + df.hour.str[2:]
        df.hour = df.hour.str[:5] + '-' + df.hour.str[5:]
        df.hour = df.hour.str[:8] + ' ' + df.hour.str[8:]
        df.hour = pd.to_datetime(df.hour, format='%y-%m-%d %H')

        df.index += index_start
    
        j+=1
        print('{} seconds: completed {} rows'.format((dt.datetime.now() - start).seconds, j*chunksize))

        df.to_sql('data', disk_engine, if_exists='append')
        index_start = df.index[-1] + 1

convert_csv_to_sqldb('../capstone_project/data/train.csv')
# Out:
# 0 seconds: completed 20000 rows
# 1 seconds: completed 40000 rows
# 2 seconds: completed 60000 rows
# 4 seconds: completed 80000 rows
# 5 seconds: completed 100000 rows
# 6 seconds: completed 120000 rows
# 7 seconds: completed 140000 rows
# 9 seconds: completed 160000 rows
# 10 seconds: completed 180000 rows
# 11 seconds: completed 200000 rows
# 12 seconds: completed 220000 rows
# 13 seconds: completed 240000 rows
# 14 seconds: completed 260000 rows
# 16 seconds: completed 280000 rows
# 17 seconds: completed 300000 rows
# 18 seconds: completed 320000 rows
# 19 seconds: completed 340000 rows
# 20 seconds: completed 360000 rows
# 21 seconds: completed 380000 rows
# 23 seconds: completed 400000 rows
# 24 seconds: completed 420000 rows
# 25 seconds: completed 440000 rows
# 26 seconds: completed 460000 rows
# 27 seconds: completed 480000 rows
# 28 seconds: completed 500000 rows
# 30 seconds: completed 520000 rows
# 31 seconds: completed 540000 rows
# 32 seconds: completed 560000 rows
# 33 seconds: completed 580000 rows
# 34 seconds: completed 600000 rows
# 35 seconds: completed 620000 rows
# 37 seconds: completed 640000 rows
# 38 seconds: completed 660000 rows
# 39 seconds: completed 680000 rows
# 40 seconds: completed 700000 rows
# 41 seconds: completed 720000 rows
# 42 seconds: completed 740000 rows
# 44 seconds: completed 760000 rows
# 45 seconds: completed 780000 rows
# 46 seconds: completed 800000 rows
# 47 seconds: completed 820000 rows
# 48 seconds: completed 840000 rows
# 49 seconds: completed 860000 rows
# 51 seconds: completed 880000 rows
# 52 seconds: completed 900000 rows
# 53 seconds: completed 920000 rows
# 54 seconds: completed 940000 rows
# 55 seconds: completed 960000 rows
# 56 seconds: completed 980000 rows
# 58 seconds: completed 1000000 rows
# 59 seconds: completed 1020000 rows
# 60 seconds: completed 1040000 rows
# 61 seconds: completed 1060000 rows
# 62 seconds: completed 1080000 rows
# 63 seconds: completed 1100000 rows
# 65 seconds: completed 1120000 rows
# 66 seconds: completed 1140000 rows
# 67 seconds: completed 1160000 rows
# 68 seconds: completed 1180000 rows
# 69 seconds: completed 1200000 rows
# 70 seconds: completed 1220000 rows
# 71 seconds: completed 1240000 rows
# 73 seconds: completed 1260000 rows
# 74 seconds: completed 1280000 rows
# 75 seconds: completed 1300000 rows
# 76 seconds: completed 1320000 rows
# 77 seconds: completed 1340000 rows
# 78 seconds: completed 1360000 rows
# 80 seconds: completed 1380000 rows
# 81 seconds: completed 1400000 rows
# 82 seconds: completed 1420000 rows
# 83 seconds: completed 1440000 rows
# 84 seconds: completed 1460000 rows
# 86 seconds: completed 1480000 rows
# 87 seconds: completed 1500000 rows
# 88 seconds: completed 1520000 rows
# 89 seconds: completed 1540000 rows
# 90 seconds: completed 1560000 rows
# 91 seconds: completed 1580000 rows
# 93 seconds: completed 1600000 rows
# 94 seconds: completed 1620000 rows
# 95 seconds: completed 1640000 rows
# 96 seconds: completed 1660000 rows
# 97 seconds: completed 1680000 rows
# 98 seconds: completed 1700000 rows
# 99 seconds: completed 1720000 rows
# 101 seconds: completed 1740000 rows
# 102 seconds: completed 1760000 rows
# 103 seconds: completed 1780000 rows
# 104 seconds: completed 1800000 rows
# 105 seconds: completed 1820000 rows
# 106 seconds: completed 1840000 rows
# 107 seconds: completed 1860000 rows
# 108 seconds: completed 1880000 rows
# 110 seconds: completed 1900000 rows
# 111 seconds: completed 1920000 rows
# 112 seconds: completed 1940000 rows
# 113 seconds: completed 1960000 rows
# 114 seconds: completed 1980000 rows
# 115 seconds: completed 2000000 rows
# 117 seconds: completed 2020000 rows
# 118 seconds: completed 2040000 rows
# 119 seconds: completed 2060000 rows
# 120 seconds: completed 2080000 rows
# 121 seconds: completed 2100000 rows
# 122 seconds: completed 2120000 rows
# 123 seconds: completed 2140000 rows
# 125 seconds: completed 2160000 rows
# 126 seconds: completed 2180000 rows
# 127 seconds: completed 2200000 rows
# 128 seconds: completed 2220000 rows
# 129 seconds: completed 2240000 rows
# 131 seconds: completed 2260000 rows
# 132 seconds: completed 2280000 rows
# 133 seconds: completed 2300000 rows
# 134 seconds: completed 2320000 rows
# 135 seconds: completed 2340000 rows
# 136 seconds: completed 2360000 rows
# 137 seconds: completed 2380000 rows
# 139 seconds: completed 2400000 rows
# 140 seconds: completed 2420000 rows
# 141 seconds: completed 2440000 rows
# 142 seconds: completed 2460000 rows
# 143 seconds: completed 2480000 rows
# 144 seconds: completed 2500000 rows
# 146 seconds: completed 2520000 rows
# 147 seconds: completed 2540000 rows
# 148 seconds: completed 2560000 rows
# 149 seconds: completed 2580000 rows
# 150 seconds: completed 2600000 rows
# 151 seconds: completed 2620000 rows
# 152 seconds: completed 2640000 rows
# 153 seconds: completed 2660000 rows
# 155 seconds: completed 2680000 rows
# 156 seconds: completed 2700000 rows
# 157 seconds: completed 2720000 rows
# 158 seconds: completed 2740000 rows
# 159 seconds: completed 2760000 rows
# 160 seconds: completed 2780000 rows
# 161 seconds: completed 2800000 rows
# 162 seconds: completed 2820000 rows
# 164 seconds: completed 2840000 rows
# 165 seconds: completed 2860000 rows
# 166 seconds: completed 2880000 rows
# 167 seconds: completed 2900000 rows
# 168 seconds: completed 2920000 rows
# 169 seconds: completed 2940000 rows
# 170 seconds: completed 2960000 rows
# 171 seconds: completed 2980000 rows
# 173 seconds: completed 3000000 rows
# 174 seconds: completed 3020000 rows
# 175 seconds: completed 3040000 rows
# 176 seconds: completed 3060000 rows
# 177 seconds: completed 3080000 rows
# 178 seconds: completed 3100000 rows
# 179 seconds: completed 3120000 rows
# 180 seconds: completed 3140000 rows
# 181 seconds: completed 3160000 rows
# 183 seconds: completed 3180000 rows
# 184 seconds: completed 3200000 rows
# 185 seconds: completed 3220000 rows
# 186 seconds: completed 3240000 rows
# 187 seconds: completed 3260000 rows
# 188 seconds: completed 3280000 rows
# 189 seconds: completed 3300000 rows
# 190 seconds: completed 3320000 rows
# 191 seconds: completed 3340000 rows
# 193 seconds: completed 3360000 rows
# 194 seconds: completed 3380000 rows
# 195 seconds: completed 3400000 rows
# 196 seconds: completed 3420000 rows
# 197 seconds: completed 3440000 rows
# 198 seconds: completed 3460000 rows
# 199 seconds: completed 3480000 rows
# 201 seconds: completed 3500000 rows
# 202 seconds: completed 3520000 rows
# 203 seconds: completed 3540000 rows
# 204 seconds: completed 3560000 rows
# 205 seconds: completed 3580000 rows
# 206 seconds: completed 3600000 rows
# 207 seconds: completed 3620000 rows
# 208 seconds: completed 3640000 rows
# 209 seconds: completed 3660000 rows
# 210 seconds: completed 3680000 rows
# 212 seconds: completed 3700000 rows
# 213 seconds: completed 3720000 rows
# 214 seconds: completed 3740000 rows
# 215 seconds: completed 3760000 rows
# 216 seconds: completed 3780000 rows
# 217 seconds: completed 3800000 rows
# 218 seconds: completed 3820000 rows
# 219 seconds: completed 3840000 rows
# 220 seconds: completed 3860000 rows
# 222 seconds: completed 3880000 rows
# 223 seconds: completed 3900000 rows
# 224 seconds: completed 3920000 rows
# 225 seconds: completed 3940000 rows
# 226 seconds: completed 3960000 rows
# 227 seconds: completed 3980000 rows
# 228 seconds: completed 4000000 rows
# 229 seconds: completed 4020000 rows
# 231 seconds: completed 4040000 rows
# 232 seconds: completed 4060000 rows
# 233 seconds: completed 4080000 rows
# 234 seconds: completed 4100000 rows
# 235 seconds: completed 4120000 rows
# 236 seconds: completed 4140000 rows
# 237 seconds: completed 4160000 rows
# 238 seconds: completed 4180000 rows
# 239 seconds: completed 4200000 rows
# 241 seconds: completed 4220000 rows
# 242 seconds: completed 4240000 rows
# 243 seconds: completed 4260000 rows
# 244 seconds: completed 4280000 rows
# 245 seconds: completed 4300000 rows
# 246 seconds: completed 4320000 rows
# 247 seconds: completed 4340000 rows
# 248 seconds: completed 4360000 rows
# 252 seconds: completed 4380000 rows
# 254 seconds: completed 4400000 rows
# 255 seconds: completed 4420000 rows
# 256 seconds: completed 4440000 rows
# 258 seconds: completed 4460000 rows
# 259 seconds: completed 4480000 rows
# 260 seconds: completed 4500000 rows
# 261 seconds: completed 4520000 rows
# 262 seconds: completed 4540000 rows
# 263 seconds: completed 4560000 rows
# 265 seconds: completed 4580000 rows
# 269 seconds: completed 4600000 rows
# 273 seconds: completed 4620000 rows
# 276 seconds: completed 4640000 rows
# 280 seconds: completed 4660000 rows
# 284 seconds: completed 4680000 rows
# 287 seconds: completed 4700000 rows
# 291 seconds: completed 4720000 rows
# 295 seconds: completed 4740000 rows
# 298 seconds: completed 4760000 rows
# 301 seconds: completed 4780000 rows
# 305 seconds: completed 4800000 rows
# 307 seconds: completed 4820000 rows
# 308 seconds: completed 4840000 rows
# 309 seconds: completed 4860000 rows
# 310 seconds: completed 4880000 rows
# 311 seconds: completed 4900000 rows
# 313 seconds: completed 4920000 rows
# 314 seconds: completed 4940000 rows
# 315 seconds: completed 4960000 rows
# 316 seconds: completed 4980000 rows
# 317 seconds: completed 5000000 rows
# 318 seconds: completed 5020000 rows
# 320 seconds: completed 5040000 rows
# 321 seconds: completed 5060000 rows
# 322 seconds: completed 5080000 rows
# 323 seconds: completed 5100000 rows
# 324 seconds: completed 5120000 rows
# 325 seconds: completed 5140000 rows
# 327 seconds: completed 5160000 rows
# 329 seconds: completed 5180000 rows
# 333 seconds: completed 5200000 rows
# 337 seconds: completed 5220000 rows
# 340 seconds: completed 5240000 rows
# 344 seconds: completed 5260000 rows
# 347 seconds: completed 5280000 rows
# 350 seconds: completed 5300000 rows
# 354 seconds: completed 5320000 rows
# 358 seconds: completed 5340000 rows
# 361 seconds: completed 5360000 rows
# 365 seconds: completed 5380000 rows
# 368 seconds: completed 5400000 rows
# 371 seconds: completed 5420000 rows
# 375 seconds: completed 5440000 rows
# 379 seconds: completed 5460000 rows
# 382 seconds: completed 5480000 rows
# 386 seconds: completed 5500000 rows
# 390 seconds: completed 5520000 rows
# 393 seconds: completed 5540000 rows
# 397 seconds: completed 5560000 rows
# 400 seconds: completed 5580000 rows
# 404 seconds: completed 5600000 rows
# 408 seconds: completed 5620000 rows
# 411 seconds: completed 5640000 rows
# 412 seconds: completed 5660000 rows
# 413 seconds: completed 5680000 rows
# 414 seconds: completed 5700000 rows
# 415 seconds: completed 5720000 rows
# 417 seconds: completed 5740000 rows
# 418 seconds: completed 5760000 rows
# 419 seconds: completed 5780000 rows
# 420 seconds: completed 5800000 rows
# 421 seconds: completed 5820000 rows
# 426 seconds: completed 5840000 rows
# 430 seconds: completed 5860000 rows
# 433 seconds: completed 5880000 rows
# 437 seconds: completed 5900000 rows
# 440 seconds: completed 5920000 rows
# 444 seconds: completed 5940000 rows
# 447 seconds: completed 5960000 rows
# 451 seconds: completed 5980000 rows
# 454 seconds: completed 6000000 rows
# 458 seconds: completed 6020000 rows
# 462 seconds: completed 6040000 rows
# 465 seconds: completed 6060000 rows
# 468 seconds: completed 6080000 rows
# 473 seconds: completed 6100000 rows
# 476 seconds: completed 6120000 rows
# 479 seconds: completed 6140000 rows
# 483 seconds: completed 6160000 rows
# 486 seconds: completed 6180000 rows
# 491 seconds: completed 6200000 rows
# 494 seconds: completed 6220000 rows
# 498 seconds: completed 6240000 rows
# 502 seconds: completed 6260000 rows
# 505 seconds: completed 6280000 rows
# 509 seconds: completed 6300000 rows
# 513 seconds: completed 6320000 rows
# 516 seconds: completed 6340000 rows
# 520 seconds: completed 6360000 rows
# 524 seconds: completed 6380000 rows
# 527 seconds: completed 6400000 rows
# 531 seconds: completed 6420000 rows
# 535 seconds: completed 6440000 rows
# 538 seconds: completed 6460000 rows
# 542 seconds: completed 6480000 rows
# 546 seconds: completed 6500000 rows
# 549 seconds: completed 6520000 rows
# 552 seconds: completed 6540000 rows
# 556 seconds: completed 6560000 rows
# 559 seconds: completed 6580000 rows
# 563 seconds: completed 6600000 rows
# 566 seconds: completed 6620000 rows
# 569 seconds: completed 6640000 rows
# 573 seconds: completed 6660000 rows
# 577 seconds: completed 6680000 rows
# 580 seconds: completed 6700000 rows
# 584 seconds: completed 6720000 rows
# 587 seconds: completed 6740000 rows
# 591 seconds: completed 6760000 rows
# 594 seconds: completed 6780000 rows
# 598 seconds: completed 6800000 rows
# 601 seconds: completed 6820000 rows
# 604 seconds: completed 6840000 rows
# 607 seconds: completed 6860000 rows
# 612 seconds: completed 6880000 rows
# 615 seconds: completed 6900000 rows
# 618 seconds: completed 6920000 rows
# 622 seconds: completed 6940000 rows
# 625 seconds: completed 6960000 rows
# 630 seconds: completed 6980000 rows
# 634 seconds: completed 7000000 rows
# 2160 seconds: completed 7020000 rows
# 2166 seconds: completed 7060000 rows
# 2168 seconds: completed 7080000 rows
# 2170 seconds: completed 7100000 rows
# 2171 seconds: completed 7120000 rows
# 2173 seconds: completed 7140000 rows
# 2174 seconds: completed 7160000 rows
# 2176 seconds: completed 7180000 rows
# 2177 seconds: completed 7200000 rows
# 2179 seconds: completed 7220000 rows
# 2180 seconds: completed 7240000 rows
# 2181 seconds: completed 7260000 rows
# 2183 seconds: completed 7280000 rows
# 2184 seconds: completed 7300000 rows
# 2185 seconds: completed 7320000 rows
# 2186 seconds: completed 7340000 rows
# 2187 seconds: completed 7360000 rows
# 2188 seconds: completed 7380000 rows
# 2189 seconds: completed 7400000 rows
# 2191 seconds: completed 7420000 rows
# 2192 seconds: completed 7440000 rows
# 2193 seconds: completed 7460000 rows
# 2194 seconds: completed 7480000 rows
# 2195 seconds: completed 7500000 rows
# 2196 seconds: completed 7520000 rows
# 2197 seconds: completed 7540000 rows
# 2198 seconds: completed 7560000 rows
# 2200 seconds: completed 7580000 rows
# 2201 seconds: completed 7600000 rows
# 2202 seconds: completed 7620000 rows
# 2203 seconds: completed 7640000 rows
# 2205 seconds: completed 7660000 rows
# 2206 seconds: completed 7680000 rows
# 2207 seconds: completed 7700000 rows
# 2208 seconds: completed 7720000 rows
# 2209 seconds: completed 7740000 rows
# 2210 seconds: completed 7760000 rows
# 2212 seconds: completed 7780000 rows
# 2213 seconds: completed 7800000 rows
# 2214 seconds: completed 7820000 rows
# 2215 seconds: completed 7840000 rows
# 2217 seconds: completed 7860000 rows
# 2218 seconds: completed 7880000 rows
# 2219 seconds: completed 7900000 rows
# 2221 seconds: completed 7920000 rows
# 2222 seconds: completed 7940000 rows
# 2223 seconds: completed 7960000 rows
# 2224 seconds: completed 7980000 rows
# 2226 seconds: completed 8000000 rows
# 2227 seconds: completed 8020000 rows
# 2228 seconds: completed 8040000 rows
# 2230 seconds: completed 8060000 rows
# 2231 seconds: completed 8080000 rows
# 2232 seconds: completed 8100000 rows
# 2233 seconds: completed 8120000 rows
# 2235 seconds: completed 8140000 rows
# 2236 seconds: completed 8160000 rows
# 2237 seconds: completed 8180000 rows
# 2238 seconds: completed 8200000 rows
# 2239 seconds: completed 8220000 rows
# 2241 seconds: completed 8240000 rows
# 2242 seconds: completed 8260000 rows
# 2243 seconds: completed 8280000 rows
# 2244 seconds: completed 8300000 rows
# 2245 seconds: completed 8320000 rows
# 2246 seconds: completed 8340000 rows
# 2247 seconds: completed 8360000 rows
# 2248 seconds: completed 8380000 rows
# 2250 seconds: completed 8400000 rows
# 2251 seconds: completed 8420000 rows
# 2252 seconds: completed 8440000 rows
# 2253 seconds: completed 8460000 rows
# 2254 seconds: completed 8480000 rows
# 2255 seconds: completed 8500000 rows
# 2256 seconds: completed 8520000 rows
# 2258 seconds: completed 8540000 rows
# 2259 seconds: completed 8560000 rows
# 2260 seconds: completed 8580000 rows
# 2261 seconds: completed 8600000 rows
# 2263 seconds: completed 8620000 rows
# 2264 seconds: completed 8640000 rows
# 2265 seconds: completed 8660000 rows
# 2266 seconds: completed 8680000 rows
# 2268 seconds: completed 8700000 rows
# 2269 seconds: completed 8720000 rows
# 2270 seconds: completed 8740000 rows
# 2272 seconds: completed 8760000 rows
# 2273 seconds: completed 8780000 rows
# 2274 seconds: completed 8800000 rows
# 2275 seconds: completed 8820000 rows
# 2277 seconds: completed 8840000 rows
# 2278 seconds: completed 8860000 rows
# 2279 seconds: completed 8880000 rows
# 2280 seconds: completed 8900000 rows
# 2281 seconds: completed 8920000 rows
# 2283 seconds: completed 8940000 rows
# 2284 seconds: completed 8960000 rows
# 2285 seconds: completed 8980000 rows
# 2286 seconds: completed 9000000 rows
# 2287 seconds: completed 9020000 rows
# 2289 seconds: completed 9040000 rows
# 2290 seconds: completed 9060000 rows
# 2291 seconds: completed 9080000 rows
# 2293 seconds: completed 9100000 rows
# 2294 seconds: completed 9120000 rows
# 2295 seconds: completed 9140000 rows
# 2296 seconds: completed 9160000 rows
# 2298 seconds: completed 9180000 rows
# 2299 seconds: completed 9200000 rows
# 2300 seconds: completed 9220000 rows
# 2301 seconds: completed 9240000 rows
# 2302 seconds: completed 9260000 rows
# 2304 seconds: completed 9280000 rows
# 2305 seconds: completed 9300000 rows
# 2306 seconds: completed 9320000 rows
# 2308 seconds: completed 9340000 rows
# 2309 seconds: completed 9360000 rows
# 2310 seconds: completed 9380000 rows
# 2311 seconds: completed 9400000 rows
# 2312 seconds: completed 9420000 rows
# 2314 seconds: completed 9440000 rows
# 2315 seconds: completed 9460000 rows
# 2316 seconds: completed 9480000 rows
# 2317 seconds: completed 9500000 rows
# 2319 seconds: completed 9520000 rows
# 2320 seconds: completed 9540000 rows
# 2321 seconds: completed 9560000 rows
# 2323 seconds: completed 9580000 rows
# 2324 seconds: completed 9600000 rows
# 2325 seconds: completed 9620000 rows
# 2327 seconds: completed 9640000 rows
# 2328 seconds: completed 9660000 rows
# 2329 seconds: completed 9680000 rows
# 2331 seconds: completed 9700000 rows
# 2332 seconds: completed 9720000 rows
# 2333 seconds: completed 9740000 rows
# 2335 seconds: completed 9760000 rows
# 2336 seconds: completed 9780000 rows
# 2338 seconds: completed 9800000 rows
# 2339 seconds: completed 9820000 rows
# 2340 seconds: completed 9840000 rows
# 2341 seconds: completed 9860000 rows
# 2342 seconds: completed 9880000 rows
# 2343 seconds: completed 9900000 rows
# 2345 seconds: completed 9920000 rows
# 2346 seconds: completed 9940000 rows
# 2347 seconds: completed 9960000 rows
# 2348 seconds: completed 9980000 rows
# 2349 seconds: completed 10000000 rows
# 2350 seconds: completed 10020000 rows
# 2352 seconds: completed 10040000 rows
# 2353 seconds: completed 10060000 rows
# 2354 seconds: completed 10080000 rows
# 2355 seconds: completed 10100000 rows
# 2356 seconds: completed 10120000 rows
# 2357 seconds: completed 10140000 rows
# 2358 seconds: completed 10160000 rows
# 2359 seconds: completed 10180000 rows
# 2361 seconds: completed 10200000 rows
# 2362 seconds: completed 10220000 rows
# 2363 seconds: completed 10240000 rows
# 2364 seconds: completed 10260000 rows
# 2365 seconds: completed 10280000 rows
# 2366 seconds: completed 10300000 rows
# 2367 seconds: completed 10320000 rows
# 2369 seconds: completed 10340000 rows
# 2370 seconds: completed 10360000 rows
# 2371 seconds: completed 10380000 rows
# 2372 seconds: completed 10400000 rows
# 2373 seconds: completed 10420000 rows
# 2374 seconds: completed 10440000 rows
# 2375 seconds: completed 10460000 rows
# 2377 seconds: completed 10480000 rows
# 2378 seconds: completed 10500000 rows
# 2379 seconds: completed 10520000 rows
# 2380 seconds: completed 10540000 rows
# 2381 seconds: completed 10560000 rows
# 2382 seconds: completed 10580000 rows
# 2383 seconds: completed 10600000 rows
# 2385 seconds: completed 10620000 rows
# 2386 seconds: completed 10640000 rows
# 2387 seconds: completed 10660000 rows
# 2388 seconds: completed 10680000 rows
# 2390 seconds: completed 10700000 rows
# 2391 seconds: completed 10720000 rows
# 2392 seconds: completed 10740000 rows
# 2393 seconds: completed 10760000 rows
# 2394 seconds: completed 10780000 rows
# 2395 seconds: completed 10800000 rows
# 2397 seconds: completed 10820000 rows
# 2398 seconds: completed 10840000 rows
# 2399 seconds: completed 10860000 rows
# 2400 seconds: completed 10880000 rows
# 2401 seconds: completed 10900000 rows
# 2402 seconds: completed 10920000 rows
# 2403 seconds: completed 10940000 rows
# 2405 seconds: completed 10960000 rows
# 2406 seconds: completed 10980000 rows
# 2407 seconds: completed 11000000 rows
# 2409 seconds: completed 11020000 rows
# 2410 seconds: completed 11040000 rows
# 2411 seconds: completed 11060000 rows
# 2412 seconds: completed 11080000 rows
# 2414 seconds: completed 11100000 rows
# 2415 seconds: completed 11120000 rows
# 2416 seconds: completed 11140000 rows
# 2417 seconds: completed 11160000 rows
# 2418 seconds: completed 11180000 rows
# 2420 seconds: completed 11200000 rows
# 2421 seconds: completed 11220000 rows
# 2422 seconds: completed 11240000 rows
# 2423 seconds: completed 11260000 rows
# 2424 seconds: completed 11280000 rows
# 2425 seconds: completed 11300000 rows
# 2427 seconds: completed 11320000 rows
# 2428 seconds: completed 11340000 rows
# 2429 seconds: completed 11360000 rows
# 2430 seconds: completed 11380000 rows
# 2431 seconds: completed 11400000 rows
# 2432 seconds: completed 11420000 rows
# 2433 seconds: completed 11440000 rows
# 2434 seconds: completed 11460000 rows
# 2436 seconds: completed 11480000 rows
# 2437 seconds: completed 11500000 rows
# 2438 seconds: completed 11520000 rows
# 2439 seconds: completed 11540000 rows
# 2440 seconds: completed 11560000 rows
# 2441 seconds: completed 11580000 rows
# 2443 seconds: completed 11600000 rows
# 2444 seconds: completed 11620000 rows
# 2445 seconds: completed 11640000 rows
# 2446 seconds: completed 11660000 rows
# 2447 seconds: completed 11680000 rows
# 2448 seconds: completed 11700000 rows
# 2450 seconds: completed 11720000 rows
# 2451 seconds: completed 11740000 rows
# 2452 seconds: completed 11760000 rows
# 2453 seconds: completed 11780000 rows
# 2454 seconds: completed 11800000 rows
# 2455 seconds: completed 11820000 rows
# 2456 seconds: completed 11840000 rows
# 2458 seconds: completed 11860000 rows
# 2459 seconds: completed 11880000 rows
# 2460 seconds: completed 11900000 rows
# 2461 seconds: completed 11920000 rows
# 2462 seconds: completed 11940000 rows
# 2463 seconds: completed 11960000 rows
# 2464 seconds: completed 11980000 rows
# 2465 seconds: completed 12000000 rows
# 2467 seconds: completed 12020000 rows
# 2468 seconds: completed 12040000 rows
# 2469 seconds: completed 12060000 rows
# 2470 seconds: completed 12080000 rows
# 2471 seconds: completed 12100000 rows
# 2472 seconds: completed 12120000 rows
# 2473 seconds: completed 12140000 rows
# 2475 seconds: completed 12160000 rows
# 2476 seconds: completed 12180000 rows
# 2477 seconds: completed 12200000 rows
# 2478 seconds: completed 12220000 rows
# 2479 seconds: completed 12240000 rows
# 2480 seconds: completed 12260000 rows
# 2481 seconds: completed 12280000 rows
# 2483 seconds: completed 12300000 rows
# 2484 seconds: completed 12320000 rows
# 2486 seconds: completed 12340000 rows
# 2487 seconds: completed 12360000 rows
# 2489 seconds: completed 12380000 rows
# 2490 seconds: completed 12400000 rows
# 2491 seconds: completed 12420000 rows
# 2492 seconds: completed 12440000 rows
# 2493 seconds: completed 12460000 rows
# 2495 seconds: completed 12480000 rows
# 2496 seconds: completed 12500000 rows
# 2497 seconds: completed 12520000 rows
# 2499 seconds: completed 12540000 rows
# 2501 seconds: completed 12560000 rows
# 2502 seconds: completed 12580000 rows
# 2503 seconds: completed 12600000 rows
# 2505 seconds: completed 12620000 rows
# 2506 seconds: completed 12640000 rows
# 2508 seconds: completed 12660000 rows
# 2509 seconds: completed 12680000 rows
# 2511 seconds: completed 12700000 rows
# 2512 seconds: completed 12720000 rows
# 2514 seconds: completed 12740000 rows
# 2515 seconds: completed 12760000 rows
# 2517 seconds: completed 12780000 rows
# 2518 seconds: completed 12800000 rows
# 2519 seconds: completed 12820000 rows
# 2521 seconds: completed 12840000 rows
# 2522 seconds: completed 12860000 rows
# 2524 seconds: completed 12880000 rows
# 2525 seconds: completed 12900000 rows
# 2527 seconds: completed 12920000 rows
# 2528 seconds: completed 12940000 rows
# 2529 seconds: completed 12960000 rows
# 2530 seconds: completed 12980000 rows
# 2532 seconds: completed 13000000 rows
# 2533 seconds: completed 13020000 rows
# 2534 seconds: completed 13040000 rows
# 2536 seconds: completed 13060000 rows
# 2537 seconds: completed 13080000 rows
# 2538 seconds: completed 13100000 rows
# 2539 seconds: completed 13120000 rows
# 2541 seconds: completed 13140000 rows
# 2543 seconds: completed 13160000 rows
# 2545 seconds: completed 13180000 rows
# 2546 seconds: completed 13200000 rows
# 2547 seconds: completed 13220000 rows
# 2549 seconds: completed 13240000 rows
# 2550 seconds: completed 13260000 rows
# 2551 seconds: completed 13280000 rows
# 2552 seconds: completed 13300000 rows
# 2554 seconds: completed 13320000 rows
# 2555 seconds: completed 13340000 rows
# 2556 seconds: completed 13360000 rows
# 2557 seconds: completed 13380000 rows
# 2559 seconds: completed 13400000 rows
# 2560 seconds: completed 13420000 rows
# 2561 seconds: completed 13440000 rows
# 2562 seconds: completed 13460000 rows
# 2563 seconds: completed 13480000 rows
# 2564 seconds: completed 13500000 rows
# 2566 seconds: completed 13520000 rows
# 2567 seconds: completed 13540000 rows
# 2568 seconds: completed 13560000 rows
# 2569 seconds: completed 13580000 rows
# 2570 seconds: completed 13600000 rows
# 2571 seconds: completed 13620000 rows
# 2572 seconds: completed 13640000 rows
# 2574 seconds: completed 13660000 rows
# 2575 seconds: completed 13680000 rows
# 2576 seconds: completed 13700000 rows
# 2577 seconds: completed 13720000 rows
# 2578 seconds: completed 13740000 rows
# 2579 seconds: completed 13760000 rows
# 2581 seconds: completed 13780000 rows
# 2582 seconds: completed 13800000 rows
# 2583 seconds: completed 13820000 rows
# 2584 seconds: completed 13840000 rows
# 2585 seconds: completed 13860000 rows
# 2586 seconds: completed 13880000 rows
# 2588 seconds: completed 13900000 rows
# 2589 seconds: completed 13920000 rows
# 2590 seconds: completed 13940000 rows
# 2591 seconds: completed 13960000 rows
# 2592 seconds: completed 13980000 rows
# 2593 seconds: completed 14000000 rows
# 2595 seconds: completed 14020000 rows
# 2596 seconds: completed 14040000 rows
# 2597 seconds: completed 14060000 rows
# 2598 seconds: completed 14080000 rows
# 2599 seconds: completed 14100000 rows
# 2600 seconds: completed 14120000 rows
# 2601 seconds: completed 14140000 rows
# 2603 seconds: completed 14160000 rows
# 2604 seconds: completed 14180000 rows
# 2605 seconds: completed 14200000 rows
# 2606 seconds: completed 14220000 rows
# 2607 seconds: completed 14240000 rows
# 2608 seconds: completed 14260000 rows
# 2609 seconds: completed 14280000 rows
# 2611 seconds: completed 14300000 rows
# 2612 seconds: completed 14320000 rows
# 2613 seconds: completed 14340000 rows
# 2614 seconds: completed 14360000 rows
# 2615 seconds: completed 14380000 rows
# 2616 seconds: completed 14400000 rows
# 2618 seconds: completed 14420000 rows
# 2619 seconds: completed 14440000 rows
# 2620 seconds: completed 14460000 rows
# 2621 seconds: completed 14480000 rows
# 2622 seconds: completed 14500000 rows
# 2623 seconds: completed 14520000 rows
# 2624 seconds: completed 14540000 rows
# 2626 seconds: completed 14560000 rows
# 2627 seconds: completed 14580000 rows
# 2628 seconds: completed 14600000 rows
# 2629 seconds: completed 14620000 rows
# 2630 seconds: completed 14640000 rows
# 2631 seconds: completed 14660000 rows
# 2633 seconds: completed 14680000 rows
# 2634 seconds: completed 14700000 rows
# 2635 seconds: completed 14720000 rows
# 2636 seconds: completed 14740000 rows
# 2637 seconds: completed 14760000 rows
# 2638 seconds: completed 14780000 rows
# 2640 seconds: completed 14800000 rows
# 2641 seconds: completed 14820000 rows
# 2642 seconds: completed 14840000 rows
# 2643 seconds: completed 14860000 rows
# 2644 seconds: completed 14880000 rows
# 2645 seconds: completed 14900000 rows
# 2647 seconds: completed 14920000 rows
# 2648 seconds: completed 14940000 rows
# 2649 seconds: completed 14960000 rows
# 2650 seconds: completed 14980000 rows
# 2651 seconds: completed 15000000 rows
# 2653 seconds: completed 15020000 rows
# 2654 seconds: completed 15040000 rows
# 2655 seconds: completed 15060000 rows
# 2656 seconds: completed 15080000 rows
# 2657 seconds: completed 15100000 rows
# 2658 seconds: completed 15120000 rows
# 2659 seconds: completed 15140000 rows
# 2661 seconds: completed 15160000 rows
# 2662 seconds: completed 15180000 rows
# 2663 seconds: completed 15200000 rows
# 2664 seconds: completed 15220000 rows
# 2665 seconds: completed 15240000 rows
# 2666 seconds: completed 15260000 rows
# 2667 seconds: completed 15280000 rows
# 2669 seconds: completed 15300000 rows
# 2670 seconds: completed 15320000 rows
# 2671 seconds: completed 15340000 rows
# 2672 seconds: completed 15360000 rows
# 2673 seconds: completed 15380000 rows
# 2674 seconds: completed 15400000 rows
# 2675 seconds: completed 15420000 rows
# 2677 seconds: completed 15440000 rows
# 2678 seconds: completed 15460000 rows
# 2679 seconds: completed 15480000 rows
# 2680 seconds: completed 15500000 rows
# 2681 seconds: completed 15520000 rows
# 2682 seconds: completed 15540000 rows
# 2683 seconds: completed 15560000 rows
# 2685 seconds: completed 15580000 rows
# 2686 seconds: completed 15600000 rows
# 2687 seconds: completed 15620000 rows
# 2688 seconds: completed 15640000 rows
# 2689 seconds: completed 15660000 rows
# 2690 seconds: completed 15680000 rows
# 2692 seconds: completed 15700000 rows
# 2693 seconds: completed 15720000 rows
# 2694 seconds: completed 15740000 rows
# 2695 seconds: completed 15760000 rows
# 2696 seconds: completed 15780000 rows
# 2697 seconds: completed 15800000 rows
# 2698 seconds: completed 15820000 rows
# 2700 seconds: completed 15840000 rows
# 2701 seconds: completed 15860000 rows
# 2702 seconds: completed 15880000 rows
# 2703 seconds: completed 15900000 rows
# 2704 seconds: completed 15920000 rows
# 2705 seconds: completed 15940000 rows
# 2707 seconds: completed 15960000 rows
# 2708 seconds: completed 15980000 rows
# 2709 seconds: completed 16000000 rows
# 2710 seconds: completed 16020000 rows
# 2711 seconds: completed 16040000 rows
# 2712 seconds: completed 16060000 rows
# 2714 seconds: completed 16080000 rows
# 2715 seconds: completed 16100000 rows
# 2716 seconds: completed 16120000 rows
# 2718 seconds: completed 16140000 rows
# 2719 seconds: completed 16160000 rows
# 2720 seconds: completed 16180000 rows
# 2721 seconds: completed 16200000 rows
# 2722 seconds: completed 16220000 rows
# 2723 seconds: completed 16240000 rows
# 2725 seconds: completed 16260000 rows
# 2726 seconds: completed 16280000 rows
# 2727 seconds: completed 16300000 rows
# 2728 seconds: completed 16320000 rows
# 2729 seconds: completed 16340000 rows
# 2730 seconds: completed 16360000 rows
# 2731 seconds: completed 16380000 rows
# 2733 seconds: completed 16400000 rows
# 2734 seconds: completed 16420000 rows
# 2735 seconds: completed 16440000 rows
# 2736 seconds: completed 16460000 rows
# 2737 seconds: completed 16480000 rows
# 2739 seconds: completed 16500000 rows
# 2740 seconds: completed 16520000 rows
# 2741 seconds: completed 16540000 rows
# 2743 seconds: completed 16560000 rows
# 2744 seconds: completed 16580000 rows
# 2746 seconds: completed 16600000 rows
# 2747 seconds: completed 16620000 rows
# 2748 seconds: completed 16640000 rows
# 2749 seconds: completed 16660000 rows
# 2751 seconds: completed 16680000 rows
# 2752 seconds: completed 16700000 rows
# 2754 seconds: completed 16720000 rows
# 2755 seconds: completed 16740000 rows
# 2757 seconds: completed 16760000 rows
# 2758 seconds: completed 16780000 rows
# 2759 seconds: completed 16800000 rows
# 2760 seconds: completed 16820000 rows
# 2761 seconds: completed 16840000 rows
# 2762 seconds: completed 16860000 rows
# 2764 seconds: completed 16880000 rows
# 2765 seconds: completed 16900000 rows
# 2766 seconds: completed 16920000 rows
# 2767 seconds: completed 16940000 rows
# 2769 seconds: completed 16960000 rows
# 2770 seconds: completed 16980000 rows
# 2772 seconds: completed 17000000 rows
# 2773 seconds: completed 17020000 rows
# 2774 seconds: completed 17040000 rows
# 2775 seconds: completed 17060000 rows
# 2777 seconds: completed 17080000 rows
# 2778 seconds: completed 17100000 rows
# 2779 seconds: completed 17120000 rows
# 2780 seconds: completed 17140000 rows
# 2782 seconds: completed 17160000 rows
# 2783 seconds: completed 17180000 rows
# 2784 seconds: completed 17200000 rows
# 2785 seconds: completed 17220000 rows
# 2786 seconds: completed 17240000 rows
# 2788 seconds: completed 17260000 rows
# 2789 seconds: completed 17280000 rows
# 2790 seconds: completed 17300000 rows
# 2791 seconds: completed 17320000 rows
# 2793 seconds: completed 17340000 rows
# 2794 seconds: completed 17360000 rows
# 2795 seconds: completed 17380000 rows
# 2796 seconds: completed 17400000 rows
# 2798 seconds: completed 17420000 rows
# 2799 seconds: completed 17440000 rows
# 2800 seconds: completed 17460000 rows
# 2801 seconds: completed 17480000 rows
# 2803 seconds: completed 17500000 rows
# 2804 seconds: completed 17520000 rows
# 2805 seconds: completed 17540000 rows
# 2806 seconds: completed 17560000 rows
# 2808 seconds: completed 17580000 rows
# 2809 seconds: completed 17600000 rows
# 2810 seconds: completed 17620000 rows
# 2811 seconds: completed 17640000 rows
# 2812 seconds: completed 17660000 rows
# 2814 seconds: completed 17680000 rows
# 2815 seconds: completed 17700000 rows
# 2816 seconds: completed 17720000 rows
# 2817 seconds: completed 17740000 rows
# 2819 seconds: completed 17760000 rows
# 2820 seconds: completed 17780000 rows
# 2821 seconds: completed 17800000 rows
# 2822 seconds: completed 17820000 rows
# 2823 seconds: completed 17840000 rows
# 2825 seconds: completed 17860000 rows
# 2826 seconds: completed 17880000 rows
# 2827 seconds: completed 17900000 rows
# 2828 seconds: completed 17920000 rows
# 2830 seconds: completed 17940000 rows
# 2831 seconds: completed 17960000 rows
# 2832 seconds: completed 17980000 rows
# 2834 seconds: completed 18000000 rows
# 2835 seconds: completed 18020000 rows
# 2836 seconds: completed 18040000 rows
# 2838 seconds: completed 18060000 rows
# 2839 seconds: completed 18080000 rows
# 2840 seconds: completed 18100000 rows
# 2841 seconds: completed 18120000 rows
# 2842 seconds: completed 18140000 rows
# 2844 seconds: completed 18160000 rows
# 2845 seconds: completed 18180000 rows
# 2846 seconds: completed 18200000 rows
# 2847 seconds: completed 18220000 rows
# 2848 seconds: completed 18240000 rows
# 2849 seconds: completed 18260000 rows
# 2850 seconds: completed 18280000 rows
# 2852 seconds: completed 18300000 rows
# 2853 seconds: completed 18320000 rows
# 2854 seconds: completed 18340000 rows
# 2855 seconds: completed 18360000 rows
# 2856 seconds: completed 18380000 rows
# 2857 seconds: completed 18400000 rows
# 2858 seconds: completed 18420000 rows
# 2860 seconds: completed 18440000 rows
# 2861 seconds: completed 18460000 rows
# 2862 seconds: completed 18480000 rows
# 2863 seconds: completed 18500000 rows
# 2864 seconds: completed 18520000 rows
# 2865 seconds: completed 18540000 rows
# 2867 seconds: completed 18560000 rows
# 2868 seconds: completed 18580000 rows
# 2869 seconds: completed 18600000 rows
# 2870 seconds: completed 18620000 rows
# 2871 seconds: completed 18640000 rows
# 2872 seconds: completed 18660000 rows
# 2873 seconds: completed 18680000 rows
# 2874 seconds: completed 18700000 rows
# 2876 seconds: completed 18720000 rows
# 2877 seconds: completed 18740000 rows
# 2878 seconds: completed 18760000 rows
# 2879 seconds: completed 18780000 rows
# 2880 seconds: completed 18800000 rows
# 2881 seconds: completed 18820000 rows
# 2883 seconds: completed 18840000 rows
# 2884 seconds: completed 18860000 rows
# 2885 seconds: completed 18880000 rows
# 2886 seconds: completed 18900000 rows
# 2887 seconds: completed 18920000 rows
# 2888 seconds: completed 18940000 rows
# 2889 seconds: completed 18960000 rows
# 2890 seconds: completed 18980000 rows
# 2892 seconds: completed 19000000 rows
# 2893 seconds: completed 19020000 rows
# 2894 seconds: completed 19040000 rows
# 2895 seconds: completed 19060000 rows
# 2896 seconds: completed 19080000 rows
# 2897 seconds: completed 19100000 rows
# 2898 seconds: completed 19120000 rows
# 2900 seconds: completed 19140000 rows
# 2901 seconds: completed 19160000 rows
# 2902 seconds: completed 19180000 rows
# 2903 seconds: completed 19200000 rows
# 2904 seconds: completed 19220000 rows
# 2905 seconds: completed 19240000 rows
# 2906 seconds: completed 19260000 rows
# 2908 seconds: completed 19280000 rows
# 2909 seconds: completed 19300000 rows
# 2910 seconds: completed 19320000 rows
# 2911 seconds: completed 19340000 rows
# 2912 seconds: completed 19360000 rows
# 2913 seconds: completed 19380000 rows
# 2914 seconds: completed 19400000 rows
# 2916 seconds: completed 19420000 rows
# 2917 seconds: completed 19440000 rows
# 2918 seconds: completed 19460000 rows
# 2919 seconds: completed 19480000 rows
# 2920 seconds: completed 19500000 rows
# 2921 seconds: completed 19520000 rows
# 2922 seconds: completed 19540000 rows
# 2924 seconds: completed 19560000 rows
# 2925 seconds: completed 19580000 rows
# 2926 seconds: completed 19600000 rows
# 2927 seconds: completed 19620000 rows
# 2928 seconds: completed 19640000 rows
# 2929 seconds: completed 19660000 rows
# 2930 seconds: completed 19680000 rows
# 2932 seconds: completed 19700000 rows
# 2933 seconds: completed 19720000 rows
# 2934 seconds: completed 19740000 rows
# 2935 seconds: completed 19760000 rows
# 2936 seconds: completed 19780000 rows
# 2937 seconds: completed 19800000 rows
# 2939 seconds: completed 19820000 rows
# 2940 seconds: completed 19840000 rows
# 2941 seconds: completed 19860000 rows
# 2942 seconds: completed 19880000 rows
# 2943 seconds: completed 19900000 rows
# 2944 seconds: completed 19920000 rows
# 2945 seconds: completed 19940000 rows
# 2947 seconds: completed 19960000 rows
# 2948 seconds: completed 19980000 rows
# 2949 seconds: completed 20000000 rows
# 2950 seconds: completed 20020000 rows
# 2951 seconds: completed 20040000 rows
# 2952 seconds: completed 20060000 rows
# 2953 seconds: completed 20080000 rows
# 2954 seconds: completed 20100000 rows
# 2956 seconds: completed 20120000 rows
# 2957 seconds: completed 20140000 rows
# 2958 seconds: completed 20160000 rows
# 2959 seconds: completed 20180000 rows
# 2960 seconds: completed 20200000 rows
# 2961 seconds: completed 20220000 rows
# 2962 seconds: completed 20240000 rows
# 2964 seconds: completed 20260000 rows
# 2965 seconds: completed 20280000 rows
# 2966 seconds: completed 20300000 rows
# 2967 seconds: completed 20320000 rows
# 2968 seconds: completed 20340000 rows
# 2969 seconds: completed 20360000 rows
# 2970 seconds: completed 20380000 rows
# 2972 seconds: completed 20400000 rows
# 2973 seconds: completed 20420000 rows
# 2974 seconds: completed 20440000 rows
# 2975 seconds: completed 20460000 rows
# 2976 seconds: completed 20480000 rows
# 2977 seconds: completed 20500000 rows
# 2979 seconds: completed 20520000 rows
# 2980 seconds: completed 20540000 rows
# 2981 seconds: completed 20560000 rows
# 2982 seconds: completed 20580000 rows
# 2983 seconds: completed 20600000 rows
# 2984 seconds: completed 20620000 rows
# 2985 seconds: completed 20640000 rows
# 2986 seconds: completed 20660000 rows
# 2988 seconds: completed 20680000 rows
# 2989 seconds: completed 20700000 rows
# 2990 seconds: completed 20720000 rows
# 2991 seconds: completed 20740000 rows
# 2992 seconds: completed 20760000 rows
# 2993 seconds: completed 20780000 rows
# 2994 seconds: completed 20800000 rows
# 2996 seconds: completed 20820000 rows
# 2997 seconds: completed 20840000 rows
# 2998 seconds: completed 20860000 rows
# 2999 seconds: completed 20880000 rows
# 3000 seconds: completed 20900000 rows
# 3001 seconds: completed 20920000 rows
# 3002 seconds: completed 20940000 rows
# 3004 seconds: completed 20960000 rows
# 3005 seconds: completed 20980000 rows
# 3006 seconds: completed 21000000 rows
# 3007 seconds: completed 21020000 rows
# 3008 seconds: completed 21040000 rows
# 3009 seconds: completed 21060000 rows
# 3010 seconds: completed 21080000 rows
# 3012 seconds: completed 21100000 rows
# 3013 seconds: completed 21120000 rows
# 3014 seconds: completed 21140000 rows
# 3015 seconds: completed 21160000 rows
# 3016 seconds: completed 21180000 rows
# 3017 seconds: completed 21200000 rows
# 3018 seconds: completed 21220000 rows
# 3020 seconds: completed 21240000 rows
# 3021 seconds: completed 21260000 rows
# 3022 seconds: completed 21280000 rows
# 3023 seconds: completed 21300000 rows
# 3024 seconds: completed 21320000 rows
# 3025 seconds: completed 21340000 rows
# 3026 seconds: completed 21360000 rows
# 3028 seconds: completed 21380000 rows
# 3029 seconds: completed 21400000 rows
# 3030 seconds: completed 21420000 rows
# 3031 seconds: completed 21440000 rows
# 3032 seconds: completed 21460000 rows
# 3033 seconds: completed 21480000 rows
# 3034 seconds: completed 21500000 rows
# 3036 seconds: completed 21520000 rows
# 3037 seconds: completed 21540000 rows
# 3038 seconds: completed 21560000 rows
# 3039 seconds: completed 21580000 rows
# 3040 seconds: completed 21600000 rows
# 3041 seconds: completed 21620000 rows
# 3042 seconds: completed 21640000 rows
# 3044 seconds: completed 21660000 rows
# 3045 seconds: completed 21680000 rows
# 3046 seconds: completed 21700000 rows
# 3047 seconds: completed 21720000 rows
# 3048 seconds: completed 21740000 rows
# 3049 seconds: completed 21760000 rows
# 3051 seconds: completed 21780000 rows
# 3052 seconds: completed 21800000 rows
# 3053 seconds: completed 21820000 rows
# 3054 seconds: completed 21840000 rows
# 3055 seconds: completed 21860000 rows
# 3056 seconds: completed 21880000 rows
# 3057 seconds: completed 21900000 rows
# 3059 seconds: completed 21920000 rows
# 3060 seconds: completed 21940000 rows
# 3061 seconds: completed 21960000 rows
# 3062 seconds: completed 21980000 rows
# 3063 seconds: completed 22000000 rows
# 3064 seconds: completed 22020000 rows
# 3066 seconds: completed 22040000 rows
# 3067 seconds: completed 22060000 rows
# 3068 seconds: completed 22080000 rows
# 3069 seconds: completed 22100000 rows
# 3070 seconds: completed 22120000 rows
# 3071 seconds: completed 22140000 rows
# 3072 seconds: completed 22160000 rows
# 3074 seconds: completed 22180000 rows
# 3075 seconds: completed 22200000 rows
# 3076 seconds: completed 22220000 rows
# 3077 seconds: completed 22240000 rows
# 3078 seconds: completed 22260000 rows
# 3079 seconds: completed 22280000 rows
# 3080 seconds: completed 22300000 rows
# 3082 seconds: completed 22320000 rows
# 3086 seconds: completed 22340000 rows
# 3091 seconds: completed 22360000 rows
# 3095 seconds: completed 22380000 rows
# 3098 seconds: completed 22400000 rows
# 3103 seconds: completed 22420000 rows
# 3106 seconds: completed 22440000 rows
# 3110 seconds: completed 22460000 rows
# 3114 seconds: completed 22480000 rows
# 3117 seconds: completed 22500000 rows
# 3121 seconds: completed 22520000 rows
# 3125 seconds: completed 22540000 rows
# 3129 seconds: completed 22560000 rows
# 3133 seconds: completed 22580000 rows
# 3137 seconds: completed 22600000 rows
# 3140 seconds: completed 22620000 rows
# 3145 seconds: completed 22640000 rows
# 3149 seconds: completed 22660000 rows
# 3150 seconds: completed 22680000 rows
# 3151 seconds: completed 22700000 rows
# 3152 seconds: completed 22720000 rows
# 3154 seconds: completed 22740000 rows
# 3155 seconds: completed 22760000 rows
# 3156 seconds: completed 22780000 rows
# 3157 seconds: completed 22800000 rows
# 3158 seconds: completed 22820000 rows
# 3160 seconds: completed 22840000 rows
# 3164 seconds: completed 22860000 rows
# 3167 seconds: completed 22880000 rows
# 3171 seconds: completed 22900000 rows
# 3175 seconds: completed 22920000 rows
# 3179 seconds: completed 22940000 rows
# 3181 seconds: completed 22960000 rows
# 3182 seconds: completed 22980000 rows
# 3183 seconds: completed 23000000 rows
# 3184 seconds: completed 23020000 rows
# 3186 seconds: completed 23040000 rows
# 3187 seconds: completed 23060000 rows
# 3188 seconds: completed 23080000 rows
# 3189 seconds: completed 23100000 rows
# 3190 seconds: completed 23120000 rows
# 3193 seconds: completed 23140000 rows
# 3197 seconds: completed 23160000 rows
# 3201 seconds: completed 23180000 rows
# 3204 seconds: completed 23200000 rows
# 3208 seconds: completed 23220000 rows
# 3211 seconds: completed 23240000 rows
# 3216 seconds: completed 23260000 rows
# 3221 seconds: completed 23280000 rows
# 3223 seconds: completed 23300000 rows
# 3224 seconds: completed 23320000 rows
# 3225 seconds: completed 23340000 rows
# 3227 seconds: completed 23360000 rows
# 3228 seconds: completed 23380000 rows
# 3229 seconds: completed 23400000 rows
# 3230 seconds: completed 23420000 rows
# 3231 seconds: completed 23440000 rows
# 3233 seconds: completed 23460000 rows
# 3237 seconds: completed 23480000 rows
# 3242 seconds: completed 23500000 rows
# 3245 seconds: completed 23520000 rows
# 3249 seconds: completed 23540000 rows
# 3253 seconds: completed 23560000 rows
# 3257 seconds: completed 23580000 rows
# 3261 seconds: completed 23600000 rows
# 3264 seconds: completed 23620000 rows
# 3269 seconds: completed 23640000 rows
# 3273 seconds: completed 23660000 rows
# 3276 seconds: completed 23680000 rows
# 3280 seconds: completed 23700000 rows
# 3284 seconds: completed 23720000 rows
# 3286 seconds: completed 23740000 rows
# 3287 seconds: completed 23760000 rows
# 3288 seconds: completed 23780000 rows
# 3289 seconds: completed 23800000 rows
# 3291 seconds: completed 23820000 rows
# 3292 seconds: completed 23840000 rows
# 3293 seconds: completed 23860000 rows
# 3294 seconds: completed 23880000 rows
# 3296 seconds: completed 23900000 rows
# 3301 seconds: completed 23920000 rows
# 3305 seconds: completed 23940000 rows
# 3309 seconds: completed 23960000 rows
# 3313 seconds: completed 23980000 rows
# 3316 seconds: completed 24000000 rows
# 3320 seconds: completed 24020000 rows
# 3324 seconds: completed 24040000 rows
# 3327 seconds: completed 24060000 rows
# 3331 seconds: completed 24080000 rows
# 3336 seconds: completed 24100000 rows
# 3339 seconds: completed 24120000 rows
# 3343 seconds: completed 24140000 rows
# 3347 seconds: completed 24160000 rows
# 3350 seconds: completed 24180000 rows
# 3354 seconds: completed 24200000 rows
# 3358 seconds: completed 24220000 rows
# 3361 seconds: completed 24240000 rows
# 3365 seconds: completed 24260000 rows
# 3369 seconds: completed 24280000 rows
# 3373 seconds: completed 24300000 rows
# 3377 seconds: completed 24320000 rows
# 3380 seconds: completed 24340000 rows
# 3385 seconds: completed 24360000 rows
# 3389 seconds: completed 24380000 rows
# 3392 seconds: completed 24400000 rows
# 3396 seconds: completed 24420000 rows
# 3400 seconds: completed 24440000 rows
# 3403 seconds: completed 24460000 rows
# 3407 seconds: completed 24480000 rows
# 3411 seconds: completed 24500000 rows
# 3415 seconds: completed 24520000 rows
# 3419 seconds: completed 24540000 rows
# 3422 seconds: completed 24560000 rows
# 3426 seconds: completed 24580000 rows
# 3430 seconds: completed 24600000 rows
# 3432 seconds: completed 24620000 rows
# 3433 seconds: completed 24640000 rows
# 3434 seconds: completed 24660000 rows
# 3435 seconds: completed 24680000 rows
# 3436 seconds: completed 24700000 rows
# 3437 seconds: completed 24720000 rows
# 3439 seconds: completed 24740000 rows
# 3440 seconds: completed 24760000 rows
# 3441 seconds: completed 24780000 rows
# 3443 seconds: completed 24800000 rows
# 3444 seconds: completed 24820000 rows
# 3445 seconds: completed 24840000 rows
# 3446 seconds: completed 24860000 rows
# 3447 seconds: completed 24880000 rows
# 3448 seconds: completed 24900000 rows
# 3450 seconds: completed 24920000 rows
# 3451 seconds: completed 24940000 rows
# 3452 seconds: completed 24960000 rows
# 3453 seconds: completed 24980000 rows
# 3454 seconds: completed 25000000 rows
# 3455 seconds: completed 25020000 rows
# 3456 seconds: completed 25040000 rows
# 3458 seconds: completed 25060000 rows
# 3459 seconds: completed 25080000 rows
# 3460 seconds: completed 25100000 rows
# 3461 seconds: completed 25120000 rows
# 3462 seconds: completed 25140000 rows
# 3463 seconds: completed 25160000 rows
# 3464 seconds: completed 25180000 rows
# 3466 seconds: completed 25200000 rows
# 3467 seconds: completed 25220000 rows
# 3468 seconds: completed 25240000 rows
# 3469 seconds: completed 25260000 rows
# 3470 seconds: completed 25280000 rows
# 3471 seconds: completed 25300000 rows
# 3472 seconds: completed 25320000 rows
# 3474 seconds: completed 25340000 rows
# 3475 seconds: completed 25360000 rows
# 3476 seconds: completed 25380000 rows
# 3477 seconds: completed 25400000 rows
# 3478 seconds: completed 25420000 rows
# 3480 seconds: completed 25440000 rows
# 3481 seconds: completed 25460000 rows
# 3482 seconds: completed 25480000 rows
# 3483 seconds: completed 25500000 rows
# 3484 seconds: completed 25520000 rows
# 3485 seconds: completed 25540000 rows
# 3487 seconds: completed 25560000 rows
# 3488 seconds: completed 25580000 rows
# 3489 seconds: completed 25600000 rows
# 3490 seconds: completed 25620000 rows
# 3491 seconds: completed 25640000 rows
# 3492 seconds: completed 25660000 rows
# 3493 seconds: completed 25680000 rows
# 3495 seconds: completed 25700000 rows
# 3496 seconds: completed 25720000 rows
# 3497 seconds: completed 25740000 rows
# 3498 seconds: completed 25760000 rows
# 3499 seconds: completed 25780000 rows
# 3500 seconds: completed 25800000 rows
# ...
# 3863 seconds: completed 32040000 rows
# 3864 seconds: completed 32060000 rows
# 3865 seconds: completed 32080000 rows
# 3866 seconds: completed 32100000 rows
# 3867 seconds: completed 32120000 rows
# 3869 seconds: completed 32140000 rows
# 3870 seconds: completed 32160000 rows
# 3871 seconds: completed 32180000 rows
# 3872 seconds: completed 32200000 rows
# 3873 seconds: completed 32220000 rows
# 3874 seconds: completed 32240000 rows
# 3876 seconds: completed 32260000 rows
# 3877 seconds: completed 32280000 rows
# 3878 seconds: completed 32300000 rows
# 3879 seconds: completed 32320000 rows
# 3880 seconds: completed 32340000 rows
# 3881 seconds: completed 32360000 rows
# 3882 seconds: completed 32380000 rows
# 3884 seconds: completed 32400000 rows
# 3885 seconds: completed 32420000 rows
# 3886 seconds: completed 32440000 rows
# 3887 seconds: completed 32460000 rows
# 3888 seconds: completed 32480000 rows
# 3890 seconds: completed 32500000 rows
# 3891 seconds: completed 32520000 rows
# 3892 seconds: completed 32540000 rows
# 3894 seconds: completed 32560000 rows
# 3895 seconds: completed 32580000 rows
# 3896 seconds: completed 32600000 rows
# 3897 seconds: completed 32620000 rows
# 3898 seconds: completed 32640000 rows
# 3900 seconds: completed 32660000 rows
# 3901 seconds: completed 32680000 rows
# 3902 seconds: completed 32700000 rows
# 3903 seconds: completed 32720000 rows
# 3905 seconds: completed 32740000 rows
# 3906 seconds: completed 32760000 rows
# 3907 seconds: completed 32780000 rows
# 3909 seconds: completed 32800000 rows
# 3910 seconds: completed 32820000 rows
# 3911 seconds: completed 32840000 rows
# 3913 seconds: completed 32860000 rows
# 3914 seconds: completed 32880000 rows
# 3915 seconds: completed 32900000 rows
# 3916 seconds: completed 32920000 rows
# 3917 seconds: completed 32940000 rows
# 3918 seconds: completed 32960000 rows
# 3920 seconds: completed 32980000 rows
# 3921 seconds: completed 33000000 rows
# 3922 seconds: completed 33020000 rows
# 3923 seconds: completed 33040000 rows
# 3925 seconds: completed 33060000 rows
# 3926 seconds: completed 33080000 rows
# 3927 seconds: completed 33100000 rows
# 3928 seconds: completed 33120000 rows
# 3930 seconds: completed 33140000 rows
# 3931 seconds: completed 33160000 rows
# 3933 seconds: completed 33180000 rows
# 3935 seconds: completed 33200000 rows
# 3936 seconds: completed 33220000 rows
# 3938 seconds: completed 33240000 rows
# 3939 seconds: completed 33260000 rows
# 3940 seconds: completed 33280000 rows
# 3941 seconds: completed 33300000 rows
# 3943 seconds: completed 33320000 rows
# 3944 seconds: completed 33340000 rows
# 3946 seconds: completed 33360000 rows
# 3947 seconds: completed 33380000 rows
# 3948 seconds: completed 33400000 rows
# 3949 seconds: completed 33420000 rows
# 3951 seconds: completed 33440000 rows
# 3952 seconds: completed 33460000 rows
# 3953 seconds: completed 33480000 rows
# 3954 seconds: completed 33500000 rows
# 3955 seconds: completed 33520000 rows
# 3957 seconds: completed 33540000 rows
# 3958 seconds: completed 33560000 rows
# 3960 seconds: completed 33580000 rows
# 3961 seconds: completed 33600000 rows
# 3963 seconds: completed 33620000 rows
# 3965 seconds: completed 33640000 rows
# 3967 seconds: completed 33660000 rows
# 3968 seconds: completed 33680000 rows
# 3969 seconds: completed 33700000 rows
# 3970 seconds: completed 33720000 rows
# 3971 seconds: completed 33740000 rows
# 3973 seconds: completed 33760000 rows
# 3974 seconds: completed 33780000 rows
# 3975 seconds: completed 33800000 rows
# 3976 seconds: completed 33820000 rows
# 3978 seconds: completed 33840000 rows
# 3979 seconds: completed 33860000 rows
# 3980 seconds: completed 33880000 rows
# 3981 seconds: completed 33900000 rows
# 3982 seconds: completed 33920000 rows
# 3984 seconds: completed 33940000 rows
# 3985 seconds: completed 33960000 rows
# 3986 seconds: completed 33980000 rows
# 3988 seconds: completed 34000000 rows
# 3989 seconds: completed 34020000 rows
# 3990 seconds: completed 34040000 rows
# 3991 seconds: completed 34060000 rows
# 3993 seconds: completed 34080000 rows
# 3994 seconds: completed 34100000 rows
# 3995 seconds: completed 34120000 rows
# 3996 seconds: completed 34140000 rows
# 3998 seconds: completed 34160000 rows
# 3999 seconds: completed 34180000 rows
# 4000 seconds: completed 34200000 rows
# 4001 seconds: completed 34220000 rows
# 4003 seconds: completed 34240000 rows
# 4004 seconds: completed 34260000 rows
# 4005 seconds: completed 34280000 rows
# 4007 seconds: completed 34300000 rows
# 4008 seconds: completed 34320000 rows
# 4010 seconds: completed 34340000 rows
# 4011 seconds: completed 34360000 rows
# 4012 seconds: completed 34380000 rows
# 4013 seconds: completed 34400000 rows
# 4015 seconds: completed 34420000 rows
# 4016 seconds: completed 34440000 rows
# 4017 seconds: completed 34460000 rows
# 4019 seconds: completed 34480000 rows
# 4020 seconds: completed 34500000 rows
# 4021 seconds: completed 34520000 rows
# 4022 seconds: completed 34540000 rows
# 4024 seconds: completed 34560000 rows
# 4025 seconds: completed 34580000 rows
# 4027 seconds: completed 34600000 rows
# 4028 seconds: completed 34620000 rows
# 4029 seconds: completed 34640000 rows
# 4030 seconds: completed 34660000 rows
# 4032 seconds: completed 34680000 rows
# 4033 seconds: completed 34700000 rows
# 4034 seconds: completed 34720000 rows
# 4036 seconds: completed 34740000 rows
# 4037 seconds: completed 34760000 rows
# 4038 seconds: completed 34780000 rows
# 4039 seconds: completed 34800000 rows
# 4041 seconds: completed 34820000 rows
# 4042 seconds: completed 34840000 rows
# 4043 seconds: completed 34860000 rows
# 4045 seconds: completed 34880000 rows
# 4046 seconds: completed 34900000 rows
# 4047 seconds: completed 34920000 rows
# 4048 seconds: completed 34940000 rows
# 4049 seconds: completed 34960000 rows
# 4051 seconds: completed 34980000 rows
# 4052 seconds: completed 35000000 rows
# 4053 seconds: completed 35020000 rows
# 4055 seconds: completed 35040000 rows
# 4056 seconds: completed 35060000 rows
# 4057 seconds: completed 35080000 rows
# 4059 seconds: completed 35100000 rows
# 4060 seconds: completed 35120000 rows
# 4061 seconds: completed 35140000 rows
# 4062 seconds: completed 35160000 rows
# 4064 seconds: completed 35180000 rows
# 4065 seconds: completed 35200000 rows
# 4066 seconds: completed 35220000 rows
# 4067 seconds: completed 35240000 rows
# 4069 seconds: completed 35260000 rows
# 4070 seconds: completed 35280000 rows
# 4071 seconds: completed 35300000 rows
# 4073 seconds: completed 35320000 rows
# 4074 seconds: completed 35340000 rows
# 4075 seconds: completed 35360000 rows
# 4076 seconds: completed 35380000 rows
# 4077 seconds: completed 35400000 rows
# 4079 seconds: completed 35420000 rows
# 4080 seconds: completed 35440000 rows
# 4081 seconds: completed 35460000 rows
# 4083 seconds: completed 35480000 rows
# 4084 seconds: completed 35500000 rows
# 4085 seconds: completed 35520000 rows
# 4086 seconds: completed 35540000 rows
# 4088 seconds: completed 35560000 rows
# 4089 seconds: completed 35580000 rows
# 4090 seconds: completed 35600000 rows
# 4091 seconds: completed 35620000 rows
# 4092 seconds: completed 35640000 rows
# 4094 seconds: completed 35660000 rows
# 4095 seconds: completed 35680000 rows
# 4096 seconds: completed 35700000 rows
# 4098 seconds: completed 35720000 rows
# 4099 seconds: completed 35740000 rows
# 4100 seconds: completed 35760000 rows
# 4101 seconds: completed 35780000 rows
# 4103 seconds: completed 35800000 rows
# 4104 seconds: completed 35820000 rows
# 4105 seconds: completed 35840000 rows
# 4107 seconds: completed 35860000 rows
# 4108 seconds: completed 35880000 rows
# 4109 seconds: completed 35900000 rows
# 4110 seconds: completed 35920000 rows
# 4112 seconds: completed 35940000 rows
# 4113 seconds: completed 35960000 rows
# 4114 seconds: completed 35980000 rows
# 4116 seconds: completed 36000000 rows
# 4117 seconds: completed 36020000 rows
# 4118 seconds: completed 36040000 rows
# 4119 seconds: completed 36060000 rows
# 4120 seconds: completed 36080000 rows
# 4122 seconds: completed 36100000 rows
# 4123 seconds: completed 36120000 rows
# 4124 seconds: completed 36140000 rows
# 4125 seconds: completed 36160000 rows
# 4127 seconds: completed 36180000 rows
# 4128 seconds: completed 36200000 rows
# 4129 seconds: completed 36220000 rows
# 4131 seconds: completed 36240000 rows
# 4132 seconds: completed 36260000 rows
# 4134 seconds: completed 36280000 rows
# 4135 seconds: completed 36300000 rows
# 4136 seconds: completed 36320000 rows
# 4137 seconds: completed 36340000 rows
# 4139 seconds: completed 36360000 rows
# 4140 seconds: completed 36380000 rows
# 4141 seconds: completed 36400000 rows
# 4143 seconds: completed 36420000 rows
# 4144 seconds: completed 36440000 rows
# 4145 seconds: completed 36460000 rows
# 4146 seconds: completed 36480000 rows
# 4148 seconds: completed 36500000 rows
# 4149 seconds: completed 36520000 rows
# 4150 seconds: completed 36540000 rows
# 4151 seconds: completed 36560000 rows
# 4152 seconds: completed 36580000 rows
# 4153 seconds: completed 36600000 rows
# 4155 seconds: completed 36620000 rows
# 4156 seconds: completed 36640000 rows
# 4157 seconds: completed 36660000 rows
# 4158 seconds: completed 36680000 rows
# 4160 seconds: completed 36700000 rows
# 4161 seconds: completed 36720000 rows
# 4162 seconds: completed 36740000 rows
# 4164 seconds: completed 36760000 rows
# 4165 seconds: completed 36780000 rows
# 4166 seconds: completed 36800000 rows
# 4167 seconds: completed 36820000 rows
# 4169 seconds: completed 36840000 rows
# 4170 seconds: completed 36860000 rows
# 4171 seconds: completed 36880000 rows
# 4173 seconds: completed 36900000 rows
# 4174 seconds: completed 36920000 rows
# 4175 seconds: completed 36940000 rows
# 4176 seconds: completed 36960000 rows
# 4178 seconds: completed 36980000 rows
# 4179 seconds: completed 37000000 rows
# 4180 seconds: completed 37020000 rows
# 4181 seconds: completed 37040000 rows
# 4182 seconds: completed 37060000 rows
# 4184 seconds: completed 37080000 rows
# 4185 seconds: completed 37100000 rows
# 4186 seconds: completed 37120000 rows
# 4187 seconds: completed 37140000 rows
# 4188 seconds: completed 37160000 rows
# 4190 seconds: completed 37180000 rows
# 4191 seconds: completed 37200000 rows
# 4192 seconds: completed 37220000 rows
# 4194 seconds: completed 37240000 rows
# 4195 seconds: completed 37260000 rows
# 4196 seconds: completed 37280000 rows
# 4198 seconds: completed 37300000 rows
# 4199 seconds: completed 37320000 rows
# 4201 seconds: completed 37340000 rows
# 4202 seconds: completed 37360000 rows
# 4203 seconds: completed 37380000 rows
# 4205 seconds: completed 37400000 rows
# 4206 seconds: completed 37420000 rows
# 4207 seconds: completed 37440000 rows
# 4208 seconds: completed 37460000 rows
# 4210 seconds: completed 37480000 rows
# 4211 seconds: completed 37500000 rows
# 4212 seconds: completed 37520000 rows
# 4214 seconds: completed 37540000 rows
# 4215 seconds: completed 37560000 rows
# 4217 seconds: completed 37580000 rows
# 4218 seconds: completed 37600000 rows
# 4219 seconds: completed 37620000 rows
# 4220 seconds: completed 37640000 rows
# 4221 seconds: completed 37660000 rows
# 4222 seconds: completed 37680000 rows
# 4224 seconds: completed 37700000 rows
# 4225 seconds: completed 37720000 rows
# 4226 seconds: completed 37740000 rows
# 4228 seconds: completed 37760000 rows
# 4229 seconds: completed 37780000 rows
# 4231 seconds: completed 37800000 rows
# 4232 seconds: completed 37820000 rows
# 4233 seconds: completed 37840000 rows
# 4235 seconds: completed 37860000 rows
# 4236 seconds: completed 37880000 rows
# 4237 seconds: completed 37900000 rows
# 4238 seconds: completed 37920000 rows
# 4240 seconds: completed 37940000 rows
# 4241 seconds: completed 37960000 rows
# 4242 seconds: completed 37980000 rows
# 4244 seconds: completed 38000000 rows
# 4245 seconds: completed 38020000 rows
# 4246 seconds: completed 38040000 rows
# 4248 seconds: completed 38060000 rows
# 4249 seconds: completed 38080000 rows
# 4250 seconds: completed 38100000 rows
# 4252 seconds: completed 38120000 rows
# 4253 seconds: completed 38140000 rows
# 4255 seconds: completed 38160000 rows
# 4256 seconds: completed 38180000 rows
# 4257 seconds: completed 38200000 rows
# 4258 seconds: completed 38220000 rows
# 4259 seconds: completed 38240000 rows
# 4261 seconds: completed 38260000 rows
# 4262 seconds: completed 38280000 rows
# 4263 seconds: completed 38300000 rows
# 4265 seconds: completed 38320000 rows
# 4266 seconds: completed 38340000 rows
# 4267 seconds: completed 38360000 rows
# 4268 seconds: completed 38380000 rows
# 4270 seconds: completed 38400000 rows
# 4271 seconds: completed 38420000 rows
# 4273 seconds: completed 38440000 rows
# 4274 seconds: completed 38460000 rows
# 4275 seconds: completed 38480000 rows
# 4276 seconds: completed 38500000 rows
# 4277 seconds: completed 38520000 rows
# 4278 seconds: completed 38540000 rows
# 4280 seconds: completed 38560000 rows
# 4281 seconds: completed 38580000 rows
# 4282 seconds: completed 38600000 rows
# 4283 seconds: completed 38620000 rows
# 4284 seconds: completed 38640000 rows
# 4285 seconds: completed 38660000 rows
# 4286 seconds: completed 38680000 rows
# 4287 seconds: completed 38700000 rows
# 4289 seconds: completed 38720000 rows
# 4290 seconds: completed 38740000 rows
# 4291 seconds: completed 38760000 rows
# 4292 seconds: completed 38780000 rows
# 4293 seconds: completed 38800000 rows
# 4294 seconds: completed 38820000 rows
# 4296 seconds: completed 38840000 rows
# 4297 seconds: completed 38860000 rows
# 4298 seconds: completed 38880000 rows
# 4299 seconds: completed 38900000 rows
# 4301 seconds: completed 38920000 rows
# 4302 seconds: completed 38940000 rows
# 4303 seconds: completed 38960000 rows
# 4304 seconds: completed 38980000 rows
# 4306 seconds: completed 39000000 rows
# 4307 seconds: completed 39020000 rows
# 4308 seconds: completed 39040000 rows
# 4309 seconds: completed 39060000 rows
# 4311 seconds: completed 39080000 rows
# 4312 seconds: completed 39100000 rows
# 4313 seconds: completed 39120000 rows
# 4314 seconds: completed 39140000 rows
# 4316 seconds: completed 39160000 rows
# 4317 seconds: completed 39180000 rows
# 4318 seconds: completed 39200000 rows
# 4320 seconds: completed 39220000 rows
# 4321 seconds: completed 39240000 rows
# 4323 seconds: completed 39260000 rows
# 4324 seconds: completed 39280000 rows
# 4325 seconds: completed 39300000 rows
# 4326 seconds: completed 39320000 rows
# 4328 seconds: completed 39340000 rows
# 4329 seconds: completed 39360000 rows
# 4330 seconds: completed 39380000 rows
# 4331 seconds: completed 39400000 rows
# 4332 seconds: completed 39420000 rows
# 4333 seconds: completed 39440000 rows
# 4334 seconds: completed 39460000 rows
# 4336 seconds: completed 39480000 rows
# 4337 seconds: completed 39500000 rows
# 4338 seconds: completed 39520000 rows
# 4339 seconds: completed 39540000 rows
# 4340 seconds: completed 39560000 rows
# 4342 seconds: completed 39580000 rows
# 4343 seconds: completed 39600000 rows
# 4344 seconds: completed 39620000 rows
# 4345 seconds: completed 39640000 rows
# 4346 seconds: completed 39660000 rows
# 4347 seconds: completed 39680000 rows
# 4349 seconds: completed 39700000 rows
# 4350 seconds: completed 39720000 rows
# 4351 seconds: completed 39740000 rows
# 4352 seconds: completed 39760000 rows
# 4354 seconds: completed 39780000 rows
# 4355 seconds: completed 39800000 rows
# 4356 seconds: completed 39820000 rows
# 4357 seconds: completed 39840000 rows
# 4358 seconds: completed 39860000 rows
# 4359 seconds: completed 39880000 rows
# 4360 seconds: completed 39900000 rows
# 4361 seconds: completed 39920000 rows
# 4362 seconds: completed 39940000 rows
# 4364 seconds: completed 39960000 rows
# 4365 seconds: completed 39980000 rows
# 4366 seconds: completed 40000000 rows
# 4367 seconds: completed 40020000 rows
# 4368 seconds: completed 40040000 rows
# 4370 seconds: completed 40060000 rows
# 4371 seconds: completed 40080000 rows
# 4372 seconds: completed 40100000 rows
# 4374 seconds: completed 40120000 rows
# 4376 seconds: completed 40140000 rows
# 4377 seconds: completed 40160000 rows
# 4378 seconds: completed 40180000 rows
# 4380 seconds: completed 40200000 rows
# 4381 seconds: completed 40220000 rows
# 4382 seconds: completed 40240000 rows
# 4384 seconds: completed 40260000 rows
# 4385 seconds: completed 40280000 rows
# 4386 seconds: completed 40300000 rows
# 4388 seconds: completed 40320000 rows
# 4389 seconds: completed 40340000 rows
# 4391 seconds: completed 40360000 rows
# 4392 seconds: completed 40380000 rows
# 4393 seconds: completed 40400000 rows
# 4394 seconds: completed 40420000 rows
# 4395 seconds: completed 40440000 rows

# %% [markdown]
# ### Check Database Integrity

# %%
import os
import pandas as pd
from sqlalchemy import create_engine # database connection

def _get_sqldb_url(relative_path):
    abs_path = os.path.abspath(relative_path)
    return ('sqlite:///' + abs_path)
    
disk_engine = create_engine(_get_sqldb_url('../capstone_project/data/train.db'))    
db_df = pd.read_sql_query('SELECT * FROM data LIMIT 3', disk_engine)
print (db_df.columns)
db_df.head()
# Out:
# Index(['index', 'id', 'click', 'hour', 'C1', 'banner_pos', 'site_id',
#        'site_domain', 'site_category', 'app_id', 'app_domain', 'app_category',
#        'device_id', 'device_ip', 'device_model', 'device_type',
#        'device_conn_type', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20',
#        'C21'],
#       dtype='object')
#    index                    id  click                        hour    C1  \
# 0      1   1000009418151094273      0  2014-10-21 00:00:00.000000  1005
# 1      2  10000169349117863715      0  2014-10-21 00:00:00.000000  1005
# 2      3  10000371904215119486      0  2014-10-21 00:00:00.000000  1005
#
#    banner_pos   site_id site_domain site_category    app_id ...  device_type  \
# 0           0  1fbe01fe    f3845767      28905ebd  ecad2386 ...            1
# 1           0  1fbe01fe    f3845767      28905ebd  ecad2386 ...            1
# 2           0  1fbe01fe    f3845767      28905ebd  ecad2386 ...            1
#
#   device_conn_type    C14  C15 C16   C17  C18  C19     C20  C21
# 0                2  15706  320  50  1722    0   35      -1   79
# 1                0  15704  320  50  1722    0   35  100084   79
# 2                0  15704  320  50  1722    0   35  100084   79
#
# [3 rows x 25 columns]
